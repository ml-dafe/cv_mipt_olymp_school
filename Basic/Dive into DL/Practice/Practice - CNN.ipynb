# %% [markdown]
# # Семинар - Сверточные нейронные сети (Convolution neural network)

# %%
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.datasets import cifar10
# Out:
# /Library/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Загрузим данные

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
print('В трейне: ', x_train.shape[0], 'объектов, в тесте: ', x_test.shape[0])
# Out:
# В трейне:  50000 объектов, в тесте:  10000

# %%
num_classes = 10 #
class_names = ['plane', 'car', 
               'bird', 'cat', 'deer', 
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Сгенерируем случаные примеры для каждого класса
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = np.transpose(features_idx[img_num,::],(0,1,2))
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
x_train, x_val, y_train, y_val =  train_test_split(x_train, y_train, test_size=3000, train_size=47000)

# %%
print('Training data shape: ', x_train.shape)
print('Validation data shape: ', x_val.shape)
print('Test data shape: ', x_test.shape)
# Out:
# Training data shape:  (47000, 32, 32, 3)
# Validation data shape:  (3000, 32, 32, 3)
# Test data shape:  (10000, 32, 32, 3)

# %% [markdown]
# ## Импорт библиотек и подготовка данных

# %%
from keras.models import Sequential # Модель, где все слои соединены друг с другом
from keras.layers import Input, Conv2D, MaxPooling2D, Dense, Dropout, Flatten 
from keras.utils import np_utils
from keras.constraints import maxnorm
from keras.optimizers import Adam

# %%
np.random.seed(18)

x_train = x_train.astype('float32')
x_val= x_val.astype('float32')
x_test = x_test.astype('float32')

# %% [markdown]
# __Масштабируем данные__

# %%
# Ваш код здесь
x_train = x_train/255 
x_val = x_val/255
x_test = x_test/255

# %%
# Закодируем целевую переменную
y_train_ohe = np_utils.to_categorical(y_train, num_classes=num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes=num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes=num_classes)

# %% [markdown]
# ## Создание CNN
# __Baseline:__
#
# - Convolutional input layer, 16 feature maps with a size of 5×5, a rectifier activation function and a weight constraint of max norm set to 3.
# - Max Pool layer with size 2×2.
# - Convolutional layer, 16 feature maps with a size of 5×5, a rectifier activation function and a weight constraint of max norm set to 3.
# - Max Pool layer with size 2×2.
# - Flatten layer.
# - Fully connected layer with 512 units and a rectifier activation function.
# - Dropout set to 50%.
# - Fully connected layer with 128 units and a rectifier activation function.
# - Dropout set to 50%.
# - Fully connected output layer with 10 units and a softmax activation function.

# %%
lrate = 1e-5

# %%
x_train.shape
# Out:
# (47000, 32, 32, 3)

# %%
# Создаем последовательную модель
model = Sequential()

model.add(Conv2D(16, (5,5), input_shape=(32, 32, 3), activation='relu',
                 kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(16, (5,5), activation='relu', 
                 kernel_constraint=maxnorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))


# Компилируем модель
adam = Adam(lr=lrate)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
print(model.summary())

# %% [markdown]
# ## Обучение CNN

# %%
epochs = 50
batch_size = 32

# %%
# Обучаем модель! 
history = model.fit(x_train, y_train_ohe,
              epochs=epochs, batch_size=batch_size,
              validation_data=(x_val, y_val_ohe),
              shuffle=True)
# Out:
# WARNING:tensorflow:From /Library/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 47000 samples, validate on 3000 samples
# Epoch 1/50
# 47000/47000 [==============================] - 65s 1ms/step - loss: 2.2974 - acc: 0.1144 - val_loss: 2.2771 - val_acc: 0.1800
# Epoch 2/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 2.2190 - acc: 0.1772 - val_loss: 2.0880 - val_acc: 0.2950
# Epoch 3/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 2.0640 - acc: 0.2248 - val_loss: 1.9464 - val_acc: 0.3227
# Epoch 4/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 1.9715 - acc: 0.2581 - val_loss: 1.8654 - val_acc: 0.3410
# Epoch 5/50
# 47000/47000 [==============================] - 60s 1ms/step - loss: 1.9077 - acc: 0.2843 - val_loss: 1.8127 - val_acc: 0.3500
# Epoch 6/50
# 47000/47000 [==============================] - 327s 7ms/step - loss: 1.8645 - acc: 0.3017 - val_loss: 1.7726 - val_acc: 0.3693
# Epoch 7/50
# 47000/47000 [==============================] - 63s 1ms/step - loss: 1.8276 - acc: 0.3182 - val_loss: 1.7383 - val_acc: 0.3823
# Epoch 8/50
# 47000/47000 [==============================] - 86s 2ms/step - loss: 1.7963 - acc: 0.3309 - val_loss: 1.7072 - val_acc: 0.3863
# Epoch 9/50
# 47000/47000 [==============================] - 64s 1ms/step - loss: 1.7732 - acc: 0.3404 - val_loss: 1.6823 - val_acc: 0.3933
# Epoch 10/50
# 47000/47000 [==============================] - 63s 1ms/step - loss: 1.7505 - acc: 0.3501 - val_loss: 1.6623 - val_acc: 0.4010
# Epoch 11/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.7270 - acc: 0.3620 - val_loss: 1.6426 - val_acc: 0.4073
# Epoch 12/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 1.7065 - acc: 0.3686 - val_loss: 1.6214 - val_acc: 0.4153
# Epoch 13/50
# 47000/47000 [==============================] - 60s 1ms/step - loss: 1.6924 - acc: 0.3755 - val_loss: 1.6092 - val_acc: 0.4130
# Epoch 14/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 1.6707 - acc: 0.3852 - val_loss: 1.5872 - val_acc: 0.4243
# Epoch 15/50
# 47000/47000 [==============================] - 60s 1ms/step - loss: 1.6540 - acc: 0.3874 - val_loss: 1.5726 - val_acc: 0.4300
# Epoch 16/50
# 47000/47000 [==============================] - 62s 1ms/step - loss: 1.6401 - acc: 0.3969 - val_loss: 1.5590 - val_acc: 0.4333
# Epoch 17/50
# 47000/47000 [==============================] - 57s 1ms/step - loss: 1.6245 - acc: 0.4063 - val_loss: 1.5465 - val_acc: 0.4413
# Epoch 18/50
# 47000/47000 [==============================] - 57s 1ms/step - loss: 1.6123 - acc: 0.4069 - val_loss: 1.5366 - val_acc: 0.4367
# Epoch 19/50
# 47000/47000 [==============================] - 57s 1ms/step - loss: 1.6003 - acc: 0.4151 - val_loss: 1.5250 - val_acc: 0.4457
# Epoch 20/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 1.5873 - acc: 0.4168 - val_loss: 1.5111 - val_acc: 0.4510
# Epoch 21/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5736 - acc: 0.4230 - val_loss: 1.5002 - val_acc: 0.4560
# Epoch 22/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5637 - acc: 0.4256 - val_loss: 1.4875 - val_acc: 0.4597
# Epoch 23/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5558 - acc: 0.4297 - val_loss: 1.4815 - val_acc: 0.4607
# Epoch 24/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5435 - acc: 0.4353 - val_loss: 1.4736 - val_acc: 0.4617
# Epoch 25/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5391 - acc: 0.4400 - val_loss: 1.4637 - val_acc: 0.4667
# Epoch 26/50
# 47000/47000 [==============================] - 58s 1ms/step - loss: 1.5276 - acc: 0.4418 - val_loss: 1.4541 - val_acc: 0.4713
# Epoch 27/50
# 47000/47000 [==============================] - 61s 1ms/step - loss: 1.5184 - acc: 0.4468 - val_loss: 1.4478 - val_acc: 0.4753
# Epoch 28/50
# 47000/47000 [==============================] - 57s 1ms/step - loss: 1.5130 - acc: 0.4477 - val_loss: 1.4471 - val_acc: 0.4703
# Epoch 29/50
# 47000/47000 [==============================] - 4160s 89ms/step - loss: 1.5023 - acc: 0.4533 - val_loss: 1.4341 - val_acc: 0.4820
# Epoch 30/50
# 47000/47000 [==============================] - 66s 1ms/step - loss: 1.4933 - acc: 0.4568 - val_loss: 1.4256 - val_acc: 0.4860
# Epoch 31/50
# 47000/47000 [==============================] - 66s 1ms/step - loss: 1.4940 - acc: 0.4555 - val_loss: 1.4187 - val_acc: 0.4890
# Epoch 32/50
# 47000/47000 [==============================] - 73s 2ms/step - loss: 1.4805 - acc: 0.4604 - val_loss: 1.4155 - val_acc: 0.4867
# Epoch 33/50
# 47000/47000 [==============================] - 69s 1ms/step - loss: 1.4758 - acc: 0.4626 - val_loss: 1.4119 - val_acc: 0.4873
# Epoch 34/50
# 47000/47000 [==============================] - 67s 1ms/step - loss: 1.4710 - acc: 0.4660 - val_loss: 1.4020 - val_acc: 0.4927
# Epoch 35/50
# 47000/47000 [==============================] - 62s 1ms/step - loss: 1.4645 - acc: 0.4687 - val_loss: 1.3980 - val_acc: 0.4920
# Epoch 36/50
# 47000/47000 [==============================] - 66s 1ms/step - loss: 1.4603 - acc: 0.4697 - val_loss: 1.3944 - val_acc: 0.4970
# Epoch 37/50
# 47000/47000 [==============================] - 64s 1ms/step - loss: 1.4525 - acc: 0.4739 - val_loss: 1.3917 - val_acc: 0.4947
# Epoch 38/50
# 47000/47000 [==============================] - 75s 2ms/step - loss: 1.4456 - acc: 0.4763 - val_loss: 1.3816 - val_acc: 0.4990
# Epoch 39/50
# 47000/47000 [==============================] - 59s 1ms/step - loss: 1.4417 - acc: 0.4775 - val_loss: 1.3789 - val_acc: 0.5010
# Epoch 40/50
# 43936/47000 [===========================>..] - ETA: 3s - loss: 1.4303 - acc: 0.4794

# %%
plt.plot(history.history['val_acc'], label='Test')
plt.plot(history.history['acc'], label='Train')
plt.xlabel('Epoch number')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
accuracy_score(y_test, model.predict_classes(x_test))

# %% [markdown]
# ## Сохранение и загрузка моделей

# %% [markdown]
# #### Сохранение модели

# %%
with open('cnn.json', 'w') as model_file:
            model_file.write(model.to_json())

# %% [markdown]
# #### Сохранение весов

# %%
model.save_weights('cnn.h5')

# %% [markdown]
# #### Загрузка модели

# %%
from keras.models import model_from_json

json_file = open("cnn.json", "r")
loaded_model_json = json_file.read()
json_file.close()
# Создаем модель на основе загруженных данных
loaded_model = model_from_json(loaded_model_json)

# %%
# Проверим
loaded_model.summary()

# %% [markdown]
# #### Загрузим обученные веса

# %%
loaded_model.load_weights("cnn.h5")

# %% [markdown]
# ## Предсказания

# %%
predict = loaded_model.predict(x_test)
predicted_class = model.predict_classes(x_test)
print('Accuracy score: ', accuracy_score(y_test, predicted_class ))

# %%
# Проверим случаный семпл:
num_pred = np.random.randint(0,999)

print('True class: ' + class_names[np.where(y_test_ohe[num_pred]==1)[0][0]])
print('Predicted class: ' + class_names[predicted_class[num_pred]])


fig, (ax1, ax2) = plt.subplots(
    nrows=1, ncols=2,
    figsize=(15, 5)
)

ax1.imshow(x_test[num_pred])
pd.Series(predict[num_pred], index=class_names).plot(kind='barh', ax=ax2, figsize=(12,4))
plt.show()

# %% [markdown]
# ## Как "видит" мир нейронная сеть

# %%
from keras import Model

# %%
# Функция для отрисовки фильтров
def plot_conv_weights(model, layer_name):
    W = model.get_layer(name=layer_name).get_weights()[0]
    if len(W.shape) == 4:
        W = np.squeeze(W)
        W = W.reshape((W.shape[0], W.shape[1], W.shape[2]*W.shape[3]))
        
        fig, axs = plt.subplots(2,8, figsize=(16,4))

        fig.subplots_adjust(hspace = .2, wspace=0.5)
        axs = axs.ravel()
        for i in range(16):
            axs[i].imshow(W[:,:,i], cmap='binary')
            axs[i].set_title(str(i+1))

# %%
plot_conv_weights(loaded_model, 'conv2d_13')
plot_conv_weights(loaded_model, 'conv2d_14')

# %%
#Выберем слой, для визуализации:

layer = 0

activation_model = Model(inputs=loaded_model.input, 
                         outputs=loaded_model.layers[layer].output)
activation_model.summary()

test_img = np.expand_dims(x_test[num_pred], axis=0)
activation = activation_model.predict(test_img)

print(activation.shape)

# %%
plt.title(class_names[np.where(y_test_ohe[num_pred]==1)[0][0]])
plt.imshow(x_test[num_pred])

fig, axs = plt.subplots(2,8, figsize=(16,4))
fig.subplots_adjust(hspace = .2, wspace=0.5)
axs = axs.ravel()
for i in range(16):
    axs[i].imshow(activation[0, :, :, i], cmap='binary')
    axs[i].set_title(str(i+1))
